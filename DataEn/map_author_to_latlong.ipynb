# %%
import findspark
import os
findspark.init()

os.environ['JAVA_HOME'] = 'C:\\Program Files\\OpenLogic\\jdk-11.0.25.9-hotspot\\'

spark_url = 'local[*]'
from pyspark.sql import SparkSession
from pyspark.sql import SQLContext
from pyspark.sql.functions import col, explode

spark = SparkSession.builder\
        .master(spark_url)\
        .appName('Spark Tutorial')\
        .config('spark.ui.port', '4040')\
        .config("spark.driver.memory", "8g") \
        .config("spark.executor.memory", "8g") \
        .config("spark.executor.cores", "4") \
        .config("spark.memory.fraction", "0.8") \
        .config("spark.driver.maxResultSize", "2g") \
        .getOrCreate()
sc = spark.sparkContext

# %%
import os

# Read all JSON files from the folder
folder_path = "data"
json_files = []
for root, dirs, files in os.walk(folder_path):
    for file in files:
        if file.endswith('.json'):
            json_files.append(os.path.join(root, file))

# Read each JSON file into a DataFrame and union them
paperDF = spark.read.json(json_files, multiLine=True)

# %%
paperDF.printSchema()
# Out:
# root
#  |-- abstracts-retrieval-response: struct (nullable = true)
#  |    |-- affiliation: string (nullable = true)
#  |    |-- authkeywords: struct (nullable = true)
#  |    |    |-- author-keyword: string (nullable = true)
#  |    |-- authors: struct (nullable = true)
#  |    |    |-- author: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- @_fa: string (nullable = true)
#  |    |    |    |    |-- @auid: string (nullable = true)
#  |    |    |    |    |-- @seq: string (nullable = true)
#  |    |    |    |    |-- affiliation: string (nullable = true)
#  |    |    |    |    |-- author-url: string (nullable = true)
#  |    |    |    |    |-- ce:alias: string (nullable = true)
#  |    |    |    |    |-- ce:alt-name: string (nullable = true)
#  |    |    |    |    |-- ce:degrees: string (nullable = true)
#  |    |    |    |    |-- ce:given-name: string (nullable = true)
#  |    |    |    |    |-- ce:indexed-name: string (nullable = true)
#  |    |    |    |    |-- ce:initials: string (nullable = true)
#  |    |    |    |    |-- ce:suffix: string (nullable = true)
#  |    |    |    |    |-- ce:surname: string (nullable = true)
#  |    |    |    |    |-- preferred-name: struct (nullable = true)
#  |    |    |    |    |    |-- ce:given-name: string (nullable = true)
#  |    |    |    |    |    |-- ce:indexed-name: string (nullable = true)
#  |    |    |    |    |    |-- ce:initials: string (nullable = true)
#  |    |    |    |    |    |-- ce:surname: string (nullable = true)
#  |    |-- coredata: struct (nullable = true)
#  |    |    |-- article-number: string (nullable = true)
#  |    |    |-- citedby-count: string (nullable = true)
#  |    |    |-- dc:creator: struct (nullable = true)
#  |    |    |    |-- author: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- @_fa: string (nullable = true)
#  |    |    |    |    |    |-- @auid: string (nullable = true)
#  |    |    |    |    |    |-- @seq: string (nullable = true)
#  |    |    |    |    |    |-- affiliation: string (nullable = true)
#  |    |    |    |    |    |-- author-url: string (nullable = true)
#  |    |    |    |    |    |-- ce:alias: string (nullable = true)
#  |    |    |    |    |    |-- ce:alt-name: string (nullable = true)
#  |    |    |    |    |    |-- ce:degrees: string (nullable = true)
#  |    |    |    |    |    |-- ce:given-name: string (nullable = true)
#  |    |    |    |    |    |-- ce:indexed-name: string (nullable = true)
#  |    |    |    |    |    |-- ce:initials: string (nullable = true)
#  |    |    |    |    |    |-- ce:suffix: string (nullable = true)
#  |    |    |    |    |    |-- ce:surname: string (nullable = true)
#  |    |    |    |    |    |-- preferred-name: struct (nullable = true)
#  |    |    |    |    |    |    |-- ce:given-name: string (nullable = true)
#  |    |    |    |    |    |    |-- ce:indexed-name: string (nullable = true)
#  |    |    |    |    |    |    |-- ce:initials: string (nullable = true)
#  |    |    |    |    |    |    |-- ce:surname: string (nullable = true)
#  |    |    |-- dc:description: string (nullable = true)
#  |    |    |-- dc:identifier: string (nullable = true)
#  |    |    |-- dc:publisher: string (nullable = true)
#  |    |    |-- dc:title: string (nullable = true)
#  |    |    |-- eid: string (nullable = true)
#  |    |    |-- link: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- @_fa: string (nullable = true)
#  |    |    |    |    |-- @href: string (nullable = true)
#  |    |    |    |    |-- @rel: string (nullable = true)
#  |    |    |-- openaccess: string (nullable = true)
#  |    |    |-- openaccessFlag: string (nullable = true)
#  |    |    |-- pii: string (nullable = true)
#  |    |    |-- prism:aggregationType: string (nullable = true)
#  |    |    |-- prism:coverDate: string (nullable = true)
#  |    |    |-- prism:doi: string (nullable = true)
#  |    |    |-- prism:endingPage: string (nullable = true)
#  |    |    |-- prism:isbn: string (nullable = true)
#  |    |    |-- prism:issn: string (nullable = true)
#  |    |    |-- prism:issueIdentifier: string (nullable = true)
#  |    |    |-- prism:pageRange: string (nullable = true)
#  |    |    |-- prism:publicationName: string (nullable = true)
#  |    |    |-- prism:startingPage: string (nullable = true)
#  |    |    |-- prism:url: string (nullable = true)
#  |    |    |-- prism:volume: string (nullable = true)
#  |    |    |-- publishercopyright: string (nullable = true)
#  |    |    |-- pubmed-id: string (nullable = true)
#  |    |    |-- source-id: string (nullable = true)
#  |    |    |-- srctype: string (nullable = true)
#  |    |    |-- subtype: string (nullable = true)
#  |    |    |-- subtypeDescription: string (nullable = true)
#  |    |-- idxterms: struct (nullable = true)
#  |    |    |-- mainterm: string (nullable = true)
#  |    |-- item: struct (nullable = true)
#  |    |    |-- ait:process-info: struct (nullable = true)
#  |    |    |    |-- ait:date-delivered: struct (nullable = true)
#  |    |    |    |    |-- @day: string (nullable = true)
#  |    |    |    |    |-- @month: string (nullable = true)
#  |    |    |    |    |-- @timestamp: string (nullable = true)
#  |    |    |    |    |-- @year: string (nullable = true)
#  |    |    |    |-- ait:date-sort: struct (nullable = true)
#  |    |    |    |    |-- @day: string (nullable = true)
#  |    |    |    |    |-- @month: string (nullable = true)
#  |    |    |    |    |-- @year: string (nullable = true)
#  |    |    |    |-- ait:status: struct (nullable = true)
#  |    |    |    |    |-- @stage: string (nullable = true)
#  |    |    |    |    |-- @state: string (nullable = true)
#  |    |    |    |    |-- @type: string (nullable = true)
#  |    |    |-- bibrecord: struct (nullable = true)
#  |    |    |    |-- head: struct (nullable = true)
#  |    |    |    |    |-- abstracts: string (nullable = true)
#  |    |    |    |    |-- author-group: string (nullable = true)
#  |    |    |    |    |-- citation-info: struct (nullable = true)
#  |    |    |    |    |    |-- abstract-language: string (nullable = true)
#  |    |    |    |    |    |-- author-keywords: struct (nullable = true)
#  |    |    |    |    |    |    |-- author-keyword: string (nullable = true)
#  |    |    |    |    |    |-- citation-language: string (nullable = true)
#  |    |    |    |    |    |-- citation-type: struct (nullable = true)
#  |    |    |    |    |    |    |-- @code: string (nullable = true)
#  |    |    |    |    |    |-- figure-information: string (nullable = true)
#  |    |    |    |    |-- citation-title: string (nullable = true)
#  |    |    |    |    |-- correspondence: string (nullable = true)
#  |    |    |    |    |-- enhancement: struct (nullable = true)
#  |    |    |    |    |    |-- chemicalgroup: struct (nullable = true)
#  |    |    |    |    |    |    |-- chemicals: string (nullable = true)
#  |    |    |    |    |    |-- classificationgroup: struct (nullable = true)
#  |    |    |    |    |    |    |-- classifications: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- @type: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- classification: string (nullable = true)
#  |    |    |    |    |    |-- descriptorgroup: struct (nullable = true)
#  |    |    |    |    |    |    |-- descriptors: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- @controlled: string (nullable = true)
#  |    |    |    |    |    |    |    |-- @type: string (nullable = true)
#  |    |    |    |    |    |    |    |-- descriptor: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- mainterm: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- $: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- @candidate: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- @weight: string (nullable = true)
#  |    |    |    |    |    |-- manufacturergroup: struct (nullable = true)
#  |    |    |    |    |    |    |-- manufacturers: string (nullable = true)
#  |    |    |    |    |    |-- sequencebanks: struct (nullable = true)
#  |    |    |    |    |    |    |-- sequencebank: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- @complete: string (nullable = true)
#  |    |    |    |    |    |    |    |-- @name: string (nullable = true)
#  |    |    |    |    |    |    |    |-- sequence-number: string (nullable = true)
#  |    |    |    |    |    |-- tradenamegroup: struct (nullable = true)
#  |    |    |    |    |    |    |-- tradenames: string (nullable = true)
#  |    |    |    |    |-- grantlist: struct (nullable = true)
#  |    |    |    |    |    |-- @complete: string (nullable = true)
#  |    |    |    |    |    |-- grant: string (nullable = true)
#  |    |    |    |    |    |-- grant-text: struct (nullable = true)
#  |    |    |    |    |    |    |-- $: string (nullable = true)
#  |    |    |    |    |    |    |-- @xml:lang: string (nullable = true)
#  |    |    |    |    |-- related-item: struct (nullable = true)
#  |    |    |    |    |    |-- @type: string (nullable = true)
#  |    |    |    |    |    |-- ce:doi: string (nullable = true)
#  |    |    |    |    |    |-- ce:ern: string (nullable = true)
#  |    |    |    |    |    |-- ce:pii: string (nullable = true)
#  |    |    |    |    |    |-- citation-info: struct (nullable = true)
#  |    |    |    |    |    |    |-- abstract-language: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- @language: string (nullable = true)
#  |    |    |    |    |    |    |    |-- @xml:lang: string (nullable = true)
#  |    |    |    |    |    |    |-- author-keywords: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- author-keyword: string (nullable = true)
#  |    |    |    |    |    |    |-- citation-language: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- @language: string (nullable = true)
#  |    |    |    |    |    |    |    |-- @xml:lang: string (nullable = true)
#  |    |    |    |    |    |    |-- citation-type: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- @code: string (nullable = true)
#  |    |    |    |    |    |-- citation-title: string (nullable = true)
#  |    |    |    |    |    |-- itemid: struct (nullable = true)
#  |    |    |    |    |    |    |-- $: string (nullable = true)
#  |    |    |    |    |    |    |-- @idtype: string (nullable = true)
#  |    |    |    |    |    |-- source: struct (nullable = true)
#  |    |    |    |    |    |    |-- @country: string (nullable = true)
#  |    |    |    |    |    |    |-- @type: string (nullable = true)
#  |    |    |    |    |    |    |-- article-number: string (nullable = true)
#  |    |    |    |    |    |    |-- bib-text: string (nullable = true)
#  |    |    |    |    |    |    |-- codencode: string (nullable = true)
#  |    |    |    |    |    |    |-- issn: string (nullable = true)
#  |    |    |    |    |    |    |-- part: string (nullable = true)
#  |    |    |    |    |    |    |-- publicationdate: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- date-text: string (nullable = true)
#  |    |    |    |    |    |    |    |-- day: string (nullable = true)
#  |    |    |    |    |    |    |    |-- month: string (nullable = true)
#  |    |    |    |    |    |    |    |-- year: string (nullable = true)
#  |    |    |    |    |    |    |-- publicationyear: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- @first: string (nullable = true)
#  |    |    |    |    |    |    |-- publisher: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- affiliation: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- @country: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- address-part: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- city: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- postal-code: string (nullable = true)
#  |    |    |    |    |    |    |    |-- ce:e-address: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- $: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- @type: string (nullable = true)
#  |    |    |    |    |    |    |    |-- publishername: string (nullable = true)
#  |    |    |    |    |    |    |-- sourcetitle: string (nullable = true)
#  |    |    |    |    |    |    |-- sourcetitle-abbrev: string (nullable = true)
#  |    |    |    |    |    |    |-- translated-sourcetitle: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- $: string (nullable = true)
#  |    |    |    |    |    |    |    |-- @xml:lang: string (nullable = true)
#  |    |    |    |    |    |    |-- volisspag: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- pagerange: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- @first: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- @last: string (nullable = true)
#  |    |    |    |    |    |    |    |-- voliss: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- @issue: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- @volume: string (nullable = true)
#  |    |    |    |    |    |    |-- website: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- ce:e-address: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- $: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- @type: string (nullable = true)
#  |    |    |    |    |-- source: struct (nullable = true)
#  |    |    |    |    |    |-- @country: string (nullable = true)
#  |    |    |    |    |    |-- @srcid: string (nullable = true)
#  |    |    |    |    |    |-- @type: string (nullable = true)
#  |    |    |    |    |    |-- additional-srcinfo: struct (nullable = true)
#  |    |    |    |    |    |    |-- conferenceinfo: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- confevent: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- confURL: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- confcatnumber: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- confcode: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- confdate: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- enddate: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- @day: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- @month: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- @year: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- startdate: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- @day: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- @month: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- @year: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- conflocation: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- @country: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- address-part: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- city: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- city-group: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- state: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- venue: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- confname: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- confnumber: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- conforganization: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- confseriestitle: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- confsponsors: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- @complete: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- confsponsor: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- conftheme: string (nullable = true)
#  |    |    |    |    |    |    |    |-- confpublication: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- procpagecount: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- procpagerange: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- procpartno: string (nullable = true)
#  |    |    |    |    |    |    |-- reportinfo: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- reportnumber: string (nullable = true)
#  |    |    |    |    |    |-- article-number: string (nullable = true)
#  |    |    |    |    |    |-- codencode: string (nullable = true)
#  |    |    |    |    |    |-- contributor-group: string (nullable = true)
#  |    |    |    |    |    |-- isbn: string (nullable = true)
#  |    |    |    |    |    |-- issn: string (nullable = true)
#  |    |    |    |    |    |-- issuetitle: string (nullable = true)
#  |    |    |    |    |    |-- part: string (nullable = true)
#  |    |    |    |    |    |-- preferred-sourcetitle: string (nullable = true)
#  |    |    |    |    |    |-- publicationdate: struct (nullable = true)
#  |    |    |    |    |    |    |-- date-text: string (nullable = true)
#  |    |    |    |    |    |    |-- day: string (nullable = true)
#  |    |    |    |    |    |    |-- month: string (nullable = true)
#  |    |    |    |    |    |    |-- year: string (nullable = true)
#  |    |    |    |    |    |-- publicationyear: struct (nullable = true)
#  |    |    |    |    |    |    |-- @first: string (nullable = true)
#  |    |    |    |    |    |    |-- @last: string (nullable = true)
#  |    |    |    |    |    |-- publisher: struct (nullable = true)
#  |    |    |    |    |    |    |-- affiliation: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- @country: string (nullable = true)
#  |    |    |    |    |    |    |    |-- address-part: string (nullable = true)
#  |    |    |    |    |    |    |    |-- city: string (nullable = true)
#  |    |    |    |    |    |    |    |-- postal-code: string (nullable = true)
#  |    |    |    |    |    |    |    |-- state: string (nullable = true)
#  |    |    |    |    |    |    |-- ce:e-address: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- $: string (nullable = true)
#  |    |    |    |    |    |    |    |-- @type: string (nullable = true)
#  |    |    |    |    |    |    |-- publishername: string (nullable = true)
#  |    |    |    |    |    |-- sourcetitle: string (nullable = true)
#  |    |    |    |    |    |-- sourcetitle-abbrev: string (nullable = true)
#  |    |    |    |    |    |-- translated-sourcetitle: struct (nullable = true)
#  |    |    |    |    |    |    |-- $: string (nullable = true)
#  |    |    |    |    |    |    |-- @xml:lang: string (nullable = true)
#  |    |    |    |    |    |-- volisspag: struct (nullable = true)
#  |    |    |    |    |    |    |-- pagecount: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- $: string (nullable = true)
#  |    |    |    |    |    |    |    |-- @type: string (nullable = true)
#  |    |    |    |    |    |    |-- pagerange: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- @first: string (nullable = true)
#  |    |    |    |    |    |    |    |-- @last: string (nullable = true)
#  |    |    |    |    |    |    |-- pages: string (nullable = true)
#  |    |    |    |    |    |    |-- supplement: string (nullable = true)
#  |    |    |    |    |    |    |-- voliss: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- @issue: string (nullable = true)
#  |    |    |    |    |    |    |    |-- @volume: string (nullable = true)
#  |    |    |    |    |    |-- volumetitle: string (nullable = true)
#  |    |    |    |    |    |-- website: string (nullable = true)
#  |    |    |    |-- item-info: struct (nullable = true)
#  |    |    |    |    |-- copyright: string (nullable = true)
#  |    |    |    |    |-- dbcollection: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- $: string (nullable = true)
#  |    |    |    |    |-- external-source: string (nullable = true)
#  |    |    |    |    |-- history: struct (nullable = true)
#  |    |    |    |    |    |-- date-created: struct (nullable = true)
#  |    |    |    |    |    |    |-- @day: string (nullable = true)
#  |    |    |    |    |    |    |-- @month: string (nullable = true)
#  |    |    |    |    |    |    |-- @timestamp: string (nullable = true)
#  |    |    |    |    |    |    |-- @year: string (nullable = true)
#  |    |    |    |    |-- itemidlist: struct (nullable = true)
#  |    |    |    |    |    |-- ce:doi: string (nullable = true)
#  |    |    |    |    |    |-- ce:ern: string (nullable = true)
#  |    |    |    |    |    |-- ce:pii: string (nullable = true)
#  |    |    |    |    |    |-- itemid: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- $: string (nullable = true)
#  |    |    |    |    |    |    |    |-- @idtype: string (nullable = true)
#  |    |    |    |-- tail: struct (nullable = true)
#  |    |    |    |    |-- bibliography: struct (nullable = true)
#  |    |    |    |    |    |-- @refcount: string (nullable = true)
#  |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |-- xocs:meta: struct (nullable = true)
#  |    |    |    |-- xocs:funding-list: struct (nullable = true)
#  |    |    |    |    |-- @has-funding-info: string (nullable = true)
#  |    |    |    |    |-- @pui-match: string (nullable = true)
#  |    |    |    |    |-- xocs:funding: string (nullable = true)
#  |    |    |    |    |-- xocs:funding-addon-generated-timestamp: string (nullable = true)
#  |    |    |    |    |-- xocs:funding-addon-type: string (nullable = true)
#  |    |    |    |    |-- xocs:funding-source-document: struct (nullable = true)
#  |    |    |    |    |    |-- $: string (nullable = true)
#  |    |    |    |    |    |-- @source-document-type: string (nullable = true)
#  |    |    |    |    |-- xocs:funding-text: string (nullable = true)
#  |    |-- language: struct (nullable = true)
#  |    |    |-- @xml:lang: string (nullable = true)
#  |    |-- subject-areas: struct (nullable = true)
#  |    |    |-- subject-area: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- $: string (nullable = true)
#  |    |    |    |    |-- @_fa: string (nullable = true)
#  |    |    |    |    |-- @abbrev: string (nullable = true)
#  |    |    |    |    |-- @code: string (nullable = true)

# %%
# Read the CSV file into a DataFrame
df = spark.read.csv('countries.csv', header=True, inferSchema=True)

# Show the DataFrame
df.show()
# Out:
# +-------+----------+-----------+--------------------+
# |country|  latitude|  longitude|                name|
# +-------+----------+-----------+--------------------+
# |     AD| 42.546245|   1.601554|             Andorra|
# |     AE| 23.424076|  53.847818|United Arab Emirates|
# |     AF|  33.93911|  67.709953|         Afghanistan|
# |     AG| 17.060816| -61.796428| Antigua and Barbuda|
# |     AI| 18.220554| -63.068615|            Anguilla|
# |     AL| 41.153332|  20.168331|             Albania|
# |     AM| 40.069099|  45.038189|             Armenia|
# |     AN| 12.226079| -69.060087|Netherlands Antilles|
# |     AO|-11.202692|  17.873887|              Angola|
# |     AQ|-75.250973|  -0.071389|          Antarctica|
# |     AR|-38.416097| -63.616672|           Argentina|
# |     AS|-14.270972|-170.132217|      American Samoa|
# |     AT| 47.516231|  14.550072|             Austria|
# |     AU|-25.274398| 133.775136|           Australia|
# |     AW|  12.52111| -69.968338|               Aruba|
# |     AZ| 40.143105|  47.576927|          Azerbaijan|
# |     BA| 43.915886|  17.679076|Bosnia and Herzeg...|
# |     BB| 13.193887| -59.543198|            Barbados|
# |     BD| 23.684994|  90.356331|          Bangladesh|
# |     BE| 50.503887|   4.469936|             Belgium|
# +-------+----------+-----------+--------------------+
# only showing top 20 rows

# %%
# Read the CSV file into a DataFrame
worldcities_df = spark.read.csv('worldcities.csv', header=True, inferSchema=True)

# Show the DataFrame
worldcities_df.show()
# Out:
# +------------+------------+--------+--------+-------------+----+----+--------------------+-------+-----------+----------+
# |        city|  city_ascii|     lat|     lng|      country|iso2|iso3|          admin_name|capital| population|        id|
# +------------+------------+--------+--------+-------------+----+----+--------------------+-------+-----------+----------+
# |       Tokyo|       Tokyo| 35.6897|139.6922|        Japan|  JP| JPN|               Tōkyō|primary|   3.7732E7|1392685764|
# |     Jakarta|     Jakarta|  -6.175|106.8275|    Indonesia|  ID| IDN|             Jakarta|primary|   3.3756E7|1360771077|
# |       Delhi|       Delhi|   28.61|   77.23|        India|  IN| IND|               Delhi|  admin|   3.2226E7|1356872604|
# |   Guangzhou|   Guangzhou|   23.13|  113.26|        China|  CN| CHN|           Guangdong|  admin|    2.694E7|1156237133|
# |      Mumbai|      Mumbai| 19.0761| 72.8775|        India|  IN| IND|         Mahārāshtra|  admin|   2.4973E7|1356226629|
# |      Manila|      Manila| 14.5958|120.9772|  Philippines|  PH| PHL|              Manila|primary|   2.4922E7|1608618140|
# |    Shanghai|    Shanghai| 31.2286|121.4747|        China|  CN| CHN|            Shanghai|  admin|   2.4073E7|1156073548|
# |   São Paulo|   Sao Paulo|  -23.55|-46.6333|       Brazil|  BR| BRA|           São Paulo|  admin|   2.3086E7|1076532519|
# |       Seoul|       Seoul|   37.56|  126.99| Korea, South|  KR| KOR|               Seoul|primary|   2.3016E7|1410836482|
# | Mexico City| Mexico City| 19.4333|-99.1333|       Mexico|  MX| MEX|    Ciudad de México|primary|   2.1804E7|1484247881|
# |       Cairo|       Cairo| 30.0444| 31.2358|        Egypt|  EG| EGY|          Al Qāhirah|primary|   2.0296E7|1818253931|
# |    New York|    New York| 40.6943|-73.9249|United States|  US| USA|            New York|   NULL|1.8908608E7|1840034016|
# |       Dhaka|       Dhaka| 23.7639| 90.3889|   Bangladesh|  BD| BGD|               Dhaka|primary|   1.8627E7|1050529279|
# |     Beijing|     Beijing| 39.9067|116.3975|        China|  CN| CHN|             Beijing|primary|   1.8522E7|1156228865|
# |     Kolkāta|     Kolkata| 22.5675|   88.37|        India|  IN| IND|         West Bengal|  admin|   1.8502E7|1356060520|
# |     Bangkok|     Bangkok| 13.7525|100.4942|     Thailand|  TH| THA|Krung Thep Maha N...|primary|   1.8007E7|1764068610|
# |    Shenzhen|    Shenzhen| 22.5415|114.0596|        China|  CN| CHN|           Guangdong|  minor|   1.7619E7|1156158707|
# |      Moscow|      Moscow| 55.7558| 37.6172|       Russia|  RU| RUS|              Moskva|primary|   1.7332E7|1643318494|
# |Buenos Aires|Buenos Aires|-34.6033|-58.3817|    Argentina|  AR| ARG|Buenos Aires, Ciu...|primary|    1.671E7|1032717330|
# |       Lagos|       Lagos|   6.455|  3.3841|      Nigeria|  NG| NGA|               Lagos|  minor|   1.6637E7|1566593751|
# +------------+------------+--------+--------+-------------+----+----+--------------------+-------+-----------+----------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import col, when, expr

# Select the affiliation column and drop null values
affiliation_df = paperDF.select("abstracts-retrieval-response.affiliation").dropna()

# Create a new column to identify the type of row
affiliation_df = affiliation_df.withColumn("row_type", 
                                           when(col("affiliation").startswith("["), "array")
                                           .when(col("affiliation").startswith("{"), "object")
                                           .otherwise("other"))

# Create DataFrames based on the row type
array_df = affiliation_df.filter(col("row_type") == "array").withColumn("affiliation", expr("explode(from_json(affiliation, 'array<string>'))"))
object_df = affiliation_df.filter(col("row_type") == "object")
other_df = affiliation_df.filter(col("row_type") == "other")

# Show the DataFrames
array_df.show()
object_df.show()
other_df.show()
# Out:
# +--------------------+--------+
# |         affiliation|row_type|
# +--------------------+--------+
# |{"affiliation-cit...|   array|
# |{"affiliation-cit...|   array|
# |{"affiliation-cit...|   array|
# |{"affiliation-cit...|   array|
# |{"affiliation-cit...|   array|
# |{"affiliation-cit...|   array|
# |{"affiliation-cit...|   array|
# |{"affiliation-cit...|   array|
# |{"affiliation-cit...|   array|
# |{"affiliation-cit...|   array|
# |{"affiliation-cit...|   array|
# |{"affiliation-cit...|   array|
# |{"affiliation-cit...|   array|
# |{"affiliation-cit...|   array|
# |{"affiliation-cit...|   array|
# |{"affiliation-cit...|   array|
# |{"affiliation-cit...|   array|
# |{"affiliation-cit...|   array|
# |{"affiliation-cit...|   array|
# |{"affiliation-cit...|   array|
# +--------------------+--------+
# only showing top 20 rows
#
# +--------------------+--------+
# |         affiliation|row_type|
# +--------------------+--------+
# |{"affiliation-cit...|  object|
# |{"affiliation-cit...|  object|
# |{"affiliation-cit...|  object|
# |{"affiliation-cit...|  object|
# |{"affiliation-cit...|  object|
# |{"affiliation-cit...|  object|
# |{"affiliation-cit...|  object|
# |{"affiliation-cit...|  object|
# |{"affiliation-cit...|  object|
# |{"affiliation-cit...|  object|
# |{"affiliation-cit...|  object|
# |{"affiliation-cit...|  object|
# |{"affiliation-cit...|  object|
# |{"affiliation-cit...|  object|
# |{"affiliation-cit...|  object|
# |{"affiliation-cit...|  object|
# |{"affiliation-cit...|  object|
# |{"affiliation-cit...|  object|
# |{"affiliation-cit...|  object|
# |{"affiliation-cit...|  object|
# +--------------------+--------+
# only showing top 20 rows
#
# +-----------+--------+
# |affiliation|row_type|
# +-----------+--------+
# +-----------+--------+

# %%
# Show 3 examples of array_df
array_df.show(3, truncate=False)

# Show 3 examples of object_df
object_df.show(3, truncate=False)
# Out:
# +---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------+
# |affiliation                                                                                                                                                                                                    |row_type|
# +---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------+
# |{"affiliation-city":"Rome","@id":"60032350","affilname":"Sapienza Università di Roma","@href":"https://api.elsevier.com/content/affiliation/affiliation_id/60032350","affiliation-country":"Italy"}            |array   |
# |{"affiliation-city":"Sao Paulo","@id":"60008088","affilname":"Universidade de São Paulo","@href":"https://api.elsevier.com/content/affiliation/affiliation_id/60008088","affiliation-country":"Brazil"}        |array   |
# |{"affiliation-city":"Buenos Aires","@id":"60001563","affilname":"Universidad de Buenos Aires","@href":"https://api.elsevier.com/content/affiliation/affiliation_id/60001563","affiliation-country":"Argentina"}|array   |
# +---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------+
# only showing top 3 rows
#
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------+
# |affiliation                                                                                                                                                                                                      |row_type|
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------+
# |{"affiliation-city":"Bangkok","@id":"60138776","affilname":"Sasin School of Management, Bangkok","@href":"https://api.elsevier.com/content/affiliation/affiliation_id/60138776","affiliation-country":"Thailand"}|object  |
# |{"affiliation-city":"Bangkok","@id":"60028190","affilname":"Chulalongkorn University","@href":"https://api.elsevier.com/content/affiliation/affiliation_id/60028190","affiliation-country":"Thailand"}           |object  |
# |{"affiliation-city":"Bangkok","@id":"60028190","affilname":"Chulalongkorn University","@href":"https://api.elsevier.com/content/affiliation/affiliation_id/60028190","affiliation-country":"Thailand"}           |object  |
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------+
# only showing top 3 rows

# %%
from pyspark.sql.functions import from_json, schema_of_json

# Define the schema for the affiliation column
affiliation_schema = schema_of_json("""
{
    "affilname": "string",
    "affiliation-city": "string",
    "affiliation-country": "string"
}
""")

# Use array_df and object_df to expand their JSON strings
expanded_array_df = array_df.withColumn("affiliation", from_json(col("affiliation"), affiliation_schema))
expanded_object_df = object_df.withColumn("affiliation", from_json(col("affiliation"), affiliation_schema))

# Select individual fields for array_df
expanded_array_df = expanded_array_df.select(
    col("affiliation.affilname").alias("affiliation_name"),
    col("affiliation.affiliation-city").alias("affiliation_city"),
    col("affiliation.affiliation-country").alias("affiliation_country")
)

# Select individual fields for object_df
expanded_object_df = expanded_object_df.select(
    col("affiliation.affilname").alias("affiliation_name"),
    col("affiliation.affiliation-city").alias("affiliation_city"),
    col("affiliation.affiliation-country").alias("affiliation_country")
)

# Show the expanded DataFrames
expanded_array_df.show()
expanded_object_df.show()
# Out:
# +--------------------+----------------+-------------------+
# |    affiliation_name|affiliation_city|affiliation_country|
# +--------------------+----------------+-------------------+
# |Sapienza Universi...|            Rome|              Italy|
# |Universidade de S...|       Sao Paulo|             Brazil|
# |Universidad de Bu...|    Buenos Aires|          Argentina|
# |Université Côte d...|            Nice|             France|
# |Washington Univer...|       St. Louis|      United States|
# |Universidad de Chile|        Santiago|              Chile|
# |Karolinska Instit...|       Stockholm|             Sweden|
# |Albert Einstein C...|        New York|      United States|
# |Université Paris ...|           Paris|             France|
# |Universidad de Se...|         Sevilla|              Spain|
# |University of Mic...|       Ann Arbor|      United States|
# | Universität zu Köln|            Koln|            Germany|
# | Kræftens Bekæmpelse|      Copenhagen|            Denmark|
# |The University of...|         Houston|      United States|
# | Sorbonne Université|           Paris|             France|
# |University of Mas...|       Worcester|      United States|
# |The First Bethune...|       Changchun|              China|
# |Université Paris-...|  Gif-sur-Yvette|             France|
# |Université de Bor...|        Bordeaux|             France|
# |University of Bel...|        Belgrade|             Serbia|
# +--------------------+----------------+-------------------+
# only showing top 20 rows
#
# +--------------------+----------------+-------------------+
# |    affiliation_name|affiliation_city|affiliation_country|
# +--------------------+----------------+-------------------+
# |Sasin School of M...|         Bangkok|           Thailand|
# |Chulalongkorn Uni...|         Bangkok|           Thailand|
# |Chulalongkorn Uni...|         Bangkok|           Thailand|
# |Chulalongkorn Uni...|         Bangkok|           Thailand|
# |Chulalongkorn Uni...|         Bangkok|           Thailand|
# |Chulalongkorn Uni...|         Bangkok|           Thailand|
# |Faculty of Medici...|         Bangkok|           Thailand|
# |Chulalongkorn Uni...|         Bangkok|           Thailand|
# |Chulalongkorn Uni...|         Bangkok|           Thailand|
# |Chulalongkorn Uni...|         Bangkok|           Thailand|
# |Faculty of Medici...|         Bangkok|           Thailand|
# |Chulalongkorn Uni...|         Bangkok|           Thailand|
# |Chulalongkorn Uni...|         Bangkok|           Thailand|
# |Faculty of Medici...|         Bangkok|           Thailand|
# |Faculty of Medici...|         Bangkok|           Thailand|
# |Chulalongkorn Uni...|         Bangkok|           Thailand|
# |Chulalongkorn Uni...|         Bangkok|           Thailand|
# |Chulalongkorn Uni...|         Bangkok|           Thailand|
# |Chulalongkorn Uni...|         Bangkok|           Thailand|
# |Chulalongkorn Uni...|         Bangkok|           Thailand|
# +--------------------+----------------+-------------------+
# only showing top 20 rows

# %%
combined_df = expanded_array_df.union(expanded_object_df)

# Show the combined DataFrame
combined_df.show()
# Out:
# +--------------------+----------------+-------------------+
# |    affiliation_name|affiliation_city|affiliation_country|
# +--------------------+----------------+-------------------+
# |Sapienza Universi...|            Rome|              Italy|
# |Universidade de S...|       Sao Paulo|             Brazil|
# |Universidad de Bu...|    Buenos Aires|          Argentina|
# |Université Côte d...|            Nice|             France|
# |Washington Univer...|       St. Louis|      United States|
# |Universidad de Chile|        Santiago|              Chile|
# |Karolinska Instit...|       Stockholm|             Sweden|
# |Albert Einstein C...|        New York|      United States|
# |Université Paris ...|           Paris|             France|
# |Universidad de Se...|         Sevilla|              Spain|
# |University of Mic...|       Ann Arbor|      United States|
# | Universität zu Köln|            Koln|            Germany|
# | Kræftens Bekæmpelse|      Copenhagen|            Denmark|
# |The University of...|         Houston|      United States|
# | Sorbonne Université|           Paris|             France|
# |University of Mas...|       Worcester|      United States|
# |The First Bethune...|       Changchun|              China|
# |Université Paris-...|  Gif-sur-Yvette|             France|
# |Université de Bor...|        Bordeaux|             France|
# |University of Bel...|        Belgrade|             Serbia|
# +--------------------+----------------+-------------------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import coalesce

# Join combined_df with worldcities_df on city and country
mapped_df = combined_df.join(worldcities_df, 
                             (combined_df.affiliation_city == worldcities_df.city_ascii) & 
                             (combined_df.affiliation_country == worldcities_df.country), 
                             how='left')

# Select the required columns
mapped_df = mapped_df.select('affiliation_name', 'affiliation_city', 'affiliation_country', 'latitude', 'longitude')

# Show the mapped DataFrame
mapped_df.show()
# Out:
# +--------------------+----------------+-------------------+--------+---------+
# |    affiliation_name|affiliation_city|affiliation_country|latitude|longitude|
# +--------------------+----------------+-------------------+--------+---------+
# |Sapienza Universi...|            Rome|              Italy| 41.8933|  12.4828|
# |Universidade de S...|       Sao Paulo|             Brazil|  -23.55| -46.6333|
# |Universidad de Bu...|    Buenos Aires|          Argentina|-34.6033| -58.3817|
# |Université Côte d...|            Nice|             France| 43.7034|   7.2663|
# |Washington Univer...|       St. Louis|      United States| 38.6359| -90.2451|
# |Universidad de Chile|        Santiago|              Chile|-33.4372| -70.6506|
# |Karolinska Instit...|       Stockholm|             Sweden| 59.3294|  18.0686|
# |Albert Einstein C...|        New York|      United States| 40.6943| -73.9249|
# |Université Paris ...|           Paris|             France| 48.8567|   2.3522|
# |Universidad de Se...|         Sevilla|              Spain|   37.39|    -5.99|
# |University of Mic...|       Ann Arbor|      United States| 42.2759|  -83.731|
# | Universität zu Köln|            Koln|            Germany|    NULL|     NULL|
# | Kræftens Bekæmpelse|      Copenhagen|            Denmark| 55.6761|  12.5683|
# |The University of...|         Houston|      United States|  29.786| -95.3885|
# | Sorbonne Université|           Paris|             France| 48.8567|   2.3522|
# |University of Mas...|       Worcester|      United States| 40.1899| -75.3522|
# |University of Mas...|       Worcester|      United States| 42.2705| -71.8079|
# |The First Bethune...|       Changchun|              China|  43.897|  125.326|
# |Université Paris-...|  Gif-sur-Yvette|             France| 48.7018|   2.1339|
# |Université de Bor...|        Bordeaux|             France|   44.84|    -0.58|
# +--------------------+----------------+-------------------+--------+---------+
# only showing top 20 rows

# %%
# Filter rows where latitude and longitude are null
null_lat_long_df = mapped_df.filter((col('latitude').isNull()) & (col('longitude').isNull()))

# Drop rows where latitude and longitude are null from the original DataFrame
filtered_mapped_df = mapped_df.filter((col('latitude').isNotNull()) & (col('longitude').isNotNull()))

# Show the new DataFrame with null latitude and longitude
null_lat_long_df.show()

# Show the filtered original DataFrame
filtered_mapped_df.show()
# Out:
# +--------------------+--------------------+-------------------+--------+---------+
# |    affiliation_name|    affiliation_city|affiliation_country|latitude|longitude|
# +--------------------+--------------------+-------------------+--------+---------+
# | Universität zu Köln|                Koln|            Germany|    NULL|     NULL|
# |           KU Leuven|         3000 Leuven|            Belgium|    NULL|     NULL|
# |NUS Yong Loo Lin ...|      Singapore City|          Singapore|    NULL|     NULL|
# |Faculty of Medici...|             Clayton|          Australia|    NULL|     NULL|
# |      Uniklinik Köln|                Koln|            Germany|    NULL|     NULL|
# |Goethe-Universitä...|   Frankfurt am Main|            Germany|    NULL|     NULL|
# |Universidad de la...|San Cristobal de ...|              Spain|    NULL|     NULL|
# |Università degli ...|               Padua|              Italy|    NULL|     NULL|
# |Departement Cellu...|              Leuven|            Belgium|    NULL|     NULL|
# |Forschungszentrum...|             Borstel|            Germany|    NULL|     NULL|
# |German Institute ...|            Nuthetal|            Germany|    NULL|     NULL|
# |Instituto de Fisi...|              Mexico|             Mexico|    NULL|     NULL|
# |   Universiteit Gent|               Ghent|            Belgium|    NULL|     NULL|
# |Universidad Nacio...|              Mexico|             Mexico|    NULL|     NULL|
# |Universidad del P...|               Leioa|              Spain|    NULL|     NULL|
# |Università degli ...|            Camerimo|              Italy|    NULL|     NULL|
# | Uniwersytet Gdanski|              Gdańsk|             Poland|    NULL|     NULL|
# |Sanford Burnham P...|        San Diego CA|      United States|    NULL|     NULL|
# |National Universi...|      Singapore City|          Singapore|    NULL|     NULL|
# |Seoul National Un...|               Seoul|        South Korea|    NULL|     NULL|
# +--------------------+--------------------+-------------------+--------+---------+
# only showing top 20 rows
#
# +--------------------+----------------+-------------------+--------+---------+
# |    affiliation_name|affiliation_city|affiliation_country|latitude|longitude|
# +--------------------+----------------+-------------------+--------+---------+
# |Sapienza Universi...|            Rome|              Italy| 41.8933|  12.4828|
# |Universidade de S...|       Sao Paulo|             Brazil|  -23.55| -46.6333|
# |Universidad de Bu...|    Buenos Aires|          Argentina|-34.6033| -58.3817|
# |Université Côte d...|            Nice|             France| 43.7034|   7.2663|
# |Washington Univer...|       St. Louis|      United States| 38.6359| -90.2451|
# |Universidad de Chile|        Santiago|              Chile|-33.4372| -70.6506|
# |Karolinska Instit...|       Stockholm|             Sweden| 59.3294|  18.0686|
# |Albert Einstein C...|        New York|      United States| 40.6943| -73.9249|
# |Université Paris ...|           Paris|             France| 48.8567|   2.3522|
# |Universidad de Se...|         Sevilla|              Spain|   37.39|    -5.99|
# |University of Mic...|       Ann Arbor|      United States| 42.2759|  -83.731|
# | Kræftens Bekæmpelse|      Copenhagen|            Denmark| 55.6761|  12.5683|
# |The University of...|         Houston|      United States|  29.786| -95.3885|
# | Sorbonne Université|           Paris|             France| 48.8567|   2.3522|
# |University of Mas...|       Worcester|      United States| 40.1899| -75.3522|
# |University of Mas...|       Worcester|      United States| 42.2705| -71.8079|
# |The First Bethune...|       Changchun|              China|  43.897|  125.326|
# |Université Paris-...|  Gif-sur-Yvette|             France| 48.7018|   2.1339|
# |Université de Bor...|        Bordeaux|             France|   44.84|    -0.58|
# |University of Bel...|        Belgrade|             Serbia|   44.82|    20.46|
# +--------------------+----------------+-------------------+--------+---------+
# only showing top 20 rows

# %%
# Drop rows with null latitude and longitude
cleaned_null_lat_long_df = null_lat_long_df.drop('latitude', 'longitude')

# Join cleaned_null_lat_long_df with df on country
mapped_country_df = cleaned_null_lat_long_df.join(df, cleaned_null_lat_long_df.affiliation_country == df.name, how='left')

# Select the required columns
mapped_country_df = mapped_country_df.select('affiliation_name', 'affiliation_city', 'affiliation_country', 'latitude', 'longitude')

# Show the mapped DataFrame
mapped_country_df.show()
# Out:
# +--------------------+--------------------+-------------------+----------+-----------+
# |    affiliation_name|    affiliation_city|affiliation_country|  latitude|  longitude|
# +--------------------+--------------------+-------------------+----------+-----------+
# | Universität zu Köln|                Koln|            Germany| 51.165691|  10.451526|
# |           KU Leuven|         3000 Leuven|            Belgium| 50.503887|   4.469936|
# |NUS Yong Loo Lin ...|      Singapore City|          Singapore|  1.352083| 103.819836|
# |Faculty of Medici...|             Clayton|          Australia|-25.274398| 133.775136|
# |      Uniklinik Köln|                Koln|            Germany| 51.165691|  10.451526|
# |Goethe-Universitä...|   Frankfurt am Main|            Germany| 51.165691|  10.451526|
# |Universidad de la...|San Cristobal de ...|              Spain| 40.463667|   -3.74922|
# |Università degli ...|               Padua|              Italy|  41.87194|   12.56738|
# |Departement Cellu...|              Leuven|            Belgium| 50.503887|   4.469936|
# |Forschungszentrum...|             Borstel|            Germany| 51.165691|  10.451526|
# |German Institute ...|            Nuthetal|            Germany| 51.165691|  10.451526|
# |Instituto de Fisi...|              Mexico|             Mexico| 23.634501|-102.552784|
# |   Universiteit Gent|               Ghent|            Belgium| 50.503887|   4.469936|
# |Universidad Nacio...|              Mexico|             Mexico| 23.634501|-102.552784|
# |Universidad del P...|               Leioa|              Spain| 40.463667|   -3.74922|
# |Università degli ...|            Camerimo|              Italy|  41.87194|   12.56738|
# | Uniwersytet Gdanski|              Gdańsk|             Poland| 51.919438|  19.145136|
# |Sanford Burnham P...|        San Diego CA|      United States|  37.09024| -95.712891|
# |National Universi...|      Singapore City|          Singapore|  1.352083| 103.819836|
# |Seoul National Un...|               Seoul|        South Korea| 35.907757| 127.766922|
# +--------------------+--------------------+-------------------+----------+-----------+
# only showing top 20 rows

# %%
# Union the DataFrames
final_df = filtered_mapped_df.union(mapped_country_df)

# Convert the final DataFrame to a Pandas DataFrame
final_pandas_df = final_df.toPandas()

# Save the Pandas DataFrame to a CSV file
final_pandas_df.to_csv('affil_location.csv', index=False)
